# %% [markdown]
# ## Testing to get class schedule data from classes.uwaterloo.ca

# %%
import mechanize
import json
from bs4 import BeautifulSoup

# %%
# declare explicit values for testing purposes
SUBJECT = 'MATH'
TERM = '1219'

# %%
# get form from website
br = mechanize.Browser()
br.open("https://classes.uwaterloo.ca/under.html")
br.select_form(action='/cgi-bin/cgiwrap/infocour/salook.pl')

# get list of terms and subjects offered
terms = [item.attrs['value'] for item in br.find_control(name='sess').items]
subjects = [item.attrs['value'] for item in br.find_control(name='subject').items]

br.find_control(name='sess').value = [TERM]
br.find_control(name='subject').value= [SUBJECT]

response = br.submit()
# response.read()

soup = BeautifulSoup(response.read(), 'html.parser')
# Out:
# ['1211', '1215', '1219', '1221']

# %%
# get main table for classes 
mainClassTable = soup.find('table', {'border': '2'})
# get iterator for children of main table
mainClassTableChildren = mainClassTable.findChildren("tr", recursive=False)
# initialize courses list
courses = []
# initialize course object
course = {}

# %%
for child in mainClassTableChildren:

    children = child.findChildren(recursive=False)
    
    # if tr is a header row, add course to classes and reinitialize the course object

    if children[0].name == 'th':
        courses += [course]

        # reinitialize course
        course = {
            'term': TERM
        }

    # if tr is a course data row, add details to the course object
    elif children[0].name == 'td' and len(children) > 2:
        course['subjectCode'] = children[0].text.strip()
        course['catalogNumber'] = children[1].text.strip()
        course['units'] = children[2].text.strip()
        course['title'] = children[3].text.strip()

    # if tr is a course notes row, add notes to the current course object
    elif children[0].name == 'td' and len(children) == 1:
        course['notes'] = children[0].text

    # if tr is a course classes row, initialize classes list and iterate over the class table to 
    # add the classes to the course
    elif children[0].name == 'td' and len(children) == 2:
        classes = []
        class_soup = BeautifulSoup(str(children[1]), 'html.parser')
        classTableRows = class_soup.find('table').find_all('tr')

        for row in classTableRows:
            indiv_class_soup = BeautifulSoup(str(row), 'html.parser')
            # if table row is not a class (ie it is just headers or notes), we ignore it  
            # we do this by checking the first element of the table row's children, as that is the class number
            # if the number is not a number, it cannot be a class, so we can ignore it
            if indiv_class_soup.find('th') != None or not indiv_class_soup.find_all('td')[0].text.strip().isnumeric():
                continue

            # otherwise, the table row is a class, and so we add it to the classes list for the courses
            else:
                subchildren = indiv_class_soup.find_all('td')
                classes += [{
                    'classNumber': subchildren[0].text.strip() if len(subchildren) >= 1 else None,
                    'section': subchildren[1].text.strip() if len(subchildren) >= 2 else None,
                    'location': subchildren[2].text.strip() if len(subchildren) >= 3 else None,
                    'enrolCap': subchildren[6].text.strip() if len(subchildren) >= 7 else None,
                    'enrolTotal': subchildren[7].text.strip() if len(subchildren) >= 8 else None,
                    'time': subchildren[10].text.strip() if len(subchildren) >= 11 else None,
                    'location': subchildren[11].text.strip() if len(subchildren) >= 12 else None,
                    'instructor': subchildren[12].text.strip() if len(subchildren) >= 13 else None,
                }]

        course['classes'] = classes

    # otherwise, the tr is an undefined row, and we ignore it
    else:
        continue

courses += [course]
# Out:
# Added course details for MATH 103
# Added course details for MATH 104
# Added course details for MATH 106
# Added course details for MATH 114
# Added course details for MATH 115
# Added course details for MATH 116
# Added course details for MATH 117
# Added course details for MATH 124
# Added course details for MATH 127
# Added course details for MATH 128
# Added course details for MATH 135
# Added course details for MATH 136
# Added course details for MATH 137
# Added course details for MATH 138
# Added course details for MATH 145
# Added course details for MATH 147
# Added course details for MATH 207
# Added course details for MATH 217
# Added course details for MATH 218
# Added course details for MATH 225
# Added course details for MATH 227
# Added course details for MATH 228
# Added course details for MATH 229
# Added course details for MATH 235
# Added course details for MATH 237
# Added course details for MATH 239
# Added course details for MATH 245
# Added course details for MATH 247
# Added course details for MATH 249

# %%
courses
# Out:
# [{},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '103',
#   'units': '0.5',
#   'title': 'Intro Algebra for Arts&Soc Sci',
#   'classes': [{'classNumber': '8192',
#     'section': 'LEC 081',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '112',
#     'time': '',
#     'instructor': 'Tuncer Karabina,Burcu'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '104',
#   'units': '0.5',
#   'title': 'Intro Calculus for Arts&SocSci',
#   'classes': [{'classNumber': '6359',
#     'section': 'LEC 081',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '98',
#     'time': '',
#     'instructor': 'Eden,Mike'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '106',
#   'units': '0.5',
#   'title': 'Applied Linear Algebra 1',
#   'classes': [{'classNumber': '6320',
#     'section': 'LEC 081',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '52',
#     'time': '',
#     'instructor': 'Garcia,Amanda'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '114',
#   'units': '0.5',
#   'title': 'Linear Algebra for Science',
#   'classes': [{'classNumber': '6260',
#     'section': 'LEC 001',
#     'location': 'B1 271',
#     'enrolCap': '96',
#     'enrolTotal': '40',
#     'time': '10:30-11:20MWF',
#     'instructor': 'Payne,Ian'},
#    {'classNumber': '6261',
#     'section': 'LEC 002',
#     'location': 'Online',
#     'enrolCap': '200',
#     'enrolTotal': '41',
#     'time': '',
#     'instructor': 'Payne,Ian'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '115',
#   'units': '0.5',
#   'title': 'Linear Algebra (Eng)',
#   'notes': '',
#   'classes': [{'classNumber': '6096',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '159',
#     'enrolTotal': '127',
#     'time': '',
#     'instructor': 'Harris,Matthew'},
#    {'classNumber': '6102',
#     'section': 'TUT 101',
#     'location': 'RCH 302',
#     'enrolCap': '53',
#     'enrolTotal': '51',
#     'time': '12:30-01:20M',
#     'instructor': None},
#    {'classNumber': '6103',
#     'section': 'TUT 102',
#     'location': 'RCH 302',
#     'enrolCap': '53',
#     'enrolTotal': '49',
#     'time': '08:30-09:20T',
#     'instructor': None},
#    {'classNumber': '6104',
#     'section': 'TUT 103',
#     'location': 'RCH 302',
#     'enrolCap': '53',
#     'enrolTotal': '27',
#     'time': '08:30-09:20Th',
#     'instructor': None},
#    {'classNumber': '6097',
#     'section': 'LEC 002',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '130',
#     'time': '',
#     'instructor': 'Geshnizjani,Ghazal'},
#    {'classNumber': '6774',
#     'section': 'TUT 104',
#     'location': 'E7 5353',
#     'enrolCap': '50',
#     'enrolTotal': '44',
#     'time': '10:30-11:20M',
#     'instructor': None},
#    {'classNumber': '6775',
#     'section': 'TUT 105',
#     'location': 'E7 5353',
#     'enrolCap': '50',
#     'enrolTotal': '45',
#     'time': '10:30-11:20T',
#     'instructor': None},
#    {'classNumber': '6776',
#     'section': 'TUT 106',
#     'location': 'E7 5353',
#     'enrolCap': '50',
#     'enrolTotal': '41',
#     'time': '10:30-11:20W',
#     'instructor': None},
#    {'classNumber': '6098',
#     'section': 'LEC 003',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '127',
#     'time': '',
#     'instructor': 'Geshnizjani,Ghazal'},
#    {'classNumber': '6777',
#     'section': 'TUT 107',
#     'location': 'E7 5353',
#     'enrolCap': '50',
#     'enrolTotal': '45',
#     'time': '11:30-12:20M',
#     'instructor': None},
#    {'classNumber': '6778',
#     'section': 'TUT 108',
#     'location': 'E7 5353',
#     'enrolCap': '50',
#     'enrolTotal': '41',
#     'time': '11:30-12:20T',
#     'instructor': None},
#    {'classNumber': '6779',
#     'section': 'TUT 109',
#     'location': 'E7 5353',
#     'enrolCap': '50',
#     'enrolTotal': '41',
#     'time': '11:30-12:20Th',
#     'instructor': None},
#    {'classNumber': '6099',
#     'section': 'LEC 004',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '143',
#     'time': '',
#     'instructor': 'Harris,Matthew'},
#    {'classNumber': '6780',
#     'section': 'TUT 110',
#     'location': 'E7 5343',
#     'enrolCap': '50',
#     'enrolTotal': '46',
#     'time': '03:30-04:20T',
#     'instructor': None},
#    {'classNumber': '6781',
#     'section': 'TUT 111',
#     'location': 'E7 5343',
#     'enrolCap': '50',
#     'enrolTotal': '52',
#     'time': '03:30-04:20W',
#     'instructor': None},
#    {'classNumber': '6782',
#     'section': 'TUT 112',
#     'location': 'E7 5343',
#     'enrolCap': '50',
#     'enrolTotal': '45',
#     'time': '03:30-04:20Th',
#     'instructor': None},
#    {'classNumber': '6100',
#     'section': 'LEC 005',
#     'location': 'Online',
#     'enrolCap': '110',
#     'enrolTotal': '101',
#     'time': '',
#     'instructor': 'Harris,Matthew'},
#    {'classNumber': '6105',
#     'section': 'TUT 113',
#     'location': 'E7 3343',
#     'enrolCap': '37',
#     'enrolTotal': '34',
#     'time': '03:30-04:20M',
#     'instructor': None},
#    {'classNumber': '6106',
#     'section': 'TUT 114',
#     'location': 'RCH 103',
#     'enrolCap': '37',
#     'enrolTotal': '33',
#     'time': '03:30-04:20W',
#     'instructor': None},
#    {'classNumber': '6107',
#     'section': 'TUT 115',
#     'location': 'RCH 103',
#     'enrolCap': '36',
#     'enrolTotal': '34',
#     'time': '02:30-03:20F',
#     'instructor': None},
#    {'classNumber': '6101',
#     'section': 'LEC 006',
#     'location': 'Online',
#     'enrolCap': '110',
#     'enrolTotal': '103',
#     'time': '',
#     'instructor': 'Trelford,Ryan'},
#    {'classNumber': '6108',
#     'section': 'TUT 116',
#     'location': 'E7 3343',
#     'enrolCap': '37',
#     'enrolTotal': '34',
#     'time': '01:30-02:20M',
#     'instructor': None},
#    {'classNumber': '6109',
#     'section': 'TUT 117',
#     'location': 'E7 3343',
#     'enrolCap': '37',
#     'enrolTotal': '35',
#     'time': '03:00-03:50W',
#     'instructor': None},
#    {'classNumber': '6110',
#     'section': 'TUT 118',
#     'location': 'E7 3343',
#     'enrolCap': '36',
#     'enrolTotal': '34',
#     'time': '01:30-02:20F',
#     'instructor': None},
#    {'classNumber': '6620',
#     'section': 'LEC 007',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '116',
#     'time': '',
#     'instructor': 'Trelford,Ryan'},
#    {'classNumber': '6111',
#     'section': 'TUT 119',
#     'location': 'E7 3343',
#     'enrolCap': '40',
#     'enrolTotal': '37',
#     'time': '09:30-10:20M',
#     'instructor': None},
#    {'classNumber': '6112',
#     'section': 'TUT 120',
#     'location': 'E7 3343',
#     'enrolCap': '40',
#     'enrolTotal': '40',
#     'time': '09:30-10:20W',
#     'instructor': None},
#    {'classNumber': '6113',
#     'section': 'TUT 121',
#     'location': 'RCH 103',
#     'enrolCap': '40',
#     'enrolTotal': '39',
#     'time': '03:30-04:20T',
#     'instructor': None},
#    {'classNumber': '6771',
#     'section': 'LEC 008',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '100',
#     'time': '',
#     'instructor': 'Trelford,Ryan'},
#    {'classNumber': '6114',
#     'section': 'TUT 122',
#     'location': 'E5 3101',
#     'enrolCap': '40',
#     'enrolTotal': '40',
#     'time': '10:30-11:20M',
#     'instructor': None},
#    {'classNumber': '6115',
#     'section': 'TUT 123',
#     'location': 'E7 3343',
#     'enrolCap': '40',
#     'enrolTotal': '35',
#     'time': '10:30-11:20T',
#     'instructor': None},
#    {'classNumber': '6116',
#     'section': 'TUT 124',
#     'location': 'E7 3343',
#     'enrolCap': '40',
#     'enrolTotal': '25',
#     'time': '09:30-10:20Th',
#     'instructor': None},
#    {'classNumber': '6772',
#     'section': 'LEC 009',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '97',
#     'time': '',
#     'instructor': 'Goldberg,Adina'},
#    {'classNumber': '6702',
#     'section': 'TUT 125',
#     'location': 'RCH 105',
#     'enrolCap': '33',
#     'enrolTotal': '34',
#     'time': '02:30-03:20M',
#     'instructor': None},
#    {'classNumber': '9613',
#     'section': 'TUT 126',
#     'location': 'RCH 105',
#     'enrolCap': '33',
#     'enrolTotal': '32',
#     'time': '02:30-03:20W',
#     'instructor': None},
#    {'classNumber': '9614',
#     'section': 'TUT 127',
#     'location': 'RCH 105',
#     'enrolCap': '34',
#     'enrolTotal': '31',
#     'time': '02:30-03:20F',
#     'instructor': None},
#    {'classNumber': '6773',
#     'section': 'LEC 010',
#     'location': 'Online',
#     'enrolCap': '154',
#     'enrolTotal': '142',
#     'time': '',
#     'instructor': 'Lai,Kwan Tsaan'},
#    {'classNumber': '9615',
#     'section': 'TUT 128',
#     'location': 'STC 0040',
#     'enrolCap': '51',
#     'enrolTotal': '45',
#     'time': '11:30-12:20W',
#     'instructor': None},
#    {'classNumber': '9616',
#     'section': 'TUT 129',
#     'location': 'STC 0040',
#     'enrolCap': '51',
#     'enrolTotal': '52',
#     'time': '09:30-10:20Th',
#     'instructor': None},
#    {'classNumber': '9617',
#     'section': 'TUT 130',
#     'location': 'STC 0040',
#     'enrolCap': '52',
#     'enrolTotal': '45',
#     'time': '11:30-12:20F',
#     'instructor': None},
#    {'classNumber': '11735',
#     'section': 'LEC 011',
#     'location': 'Online',
#     'enrolCap': '159',
#     'enrolTotal': '4',
#     'time': '',
#     'instructor': 'Harris,Matthew'},
#    {'classNumber': '11745',
#     'section': 'TUT 131',
#     'location': 'Online',
#     'enrolCap': '159',
#     'enrolTotal': '4',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11736',
#     'section': 'LEC 012',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '14',
#     'time': '',
#     'instructor': 'Geshnizjani,Ghazal'},
#    {'classNumber': '11746',
#     'section': 'TUT 132',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '14',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11737',
#     'section': 'LEC 013',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '10',
#     'time': '',
#     'instructor': 'Geshnizjani,Ghazal'},
#    {'classNumber': '11748',
#     'section': 'TUT 133',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '10',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11738',
#     'section': 'LEC 014',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '17',
#     'time': '',
#     'instructor': 'Harris,Matthew'},
#    {'classNumber': '11747',
#     'section': 'TUT 134',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '17',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11739',
#     'section': 'LEC 015',
#     'location': 'Online',
#     'enrolCap': '110',
#     'enrolTotal': '6',
#     'time': '',
#     'instructor': 'Harris,Matthew'},
#    {'classNumber': '11749',
#     'section': 'TUT 135',
#     'location': 'Online',
#     'enrolCap': '110',
#     'enrolTotal': '6',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11740',
#     'section': 'LEC 016',
#     'location': 'Online',
#     'enrolCap': '110',
#     'enrolTotal': '3',
#     'time': '',
#     'instructor': 'Trelford,Ryan'},
#    {'classNumber': '11750',
#     'section': 'TUT 136',
#     'location': 'Online',
#     'enrolCap': '110',
#     'enrolTotal': '3',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11741',
#     'section': 'LEC 017',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '1',
#     'time': '',
#     'instructor': 'Trelford,Ryan'},
#    {'classNumber': '11751',
#     'section': 'TUT 137',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '1',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11742',
#     'section': 'LEC 018',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '2',
#     'time': '',
#     'instructor': 'Trelford,Ryan'},
#    {'classNumber': '11752',
#     'section': 'TUT 138',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '2',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11743',
#     'section': 'LEC 019',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '7',
#     'time': '',
#     'instructor': 'Goldberg,Adina'},
#    {'classNumber': '11753',
#     'section': 'TUT 139',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '7',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11744',
#     'section': 'LEC 020',
#     'location': 'Online',
#     'enrolCap': '154',
#     'enrolTotal': '9',
#     'time': '',
#     'instructor': 'Lai,Kwan Tsaan'},
#    {'classNumber': '11754',
#     'section': 'TUT 140',
#     'location': 'Online',
#     'enrolCap': '154',
#     'enrolTotal': '9',
#     'time': '',
#     'instructor': None}]},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '116',
#   'units': '0.5',
#   'title': 'Calculus 1 for Engineering',
#   'notes': '',
#   'classes': [{'classNumber': '6263',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '159',
#     'enrolTotal': '126',
#     'time': '',
#     'instructor': 'Scott,Matthew'},
#    {'classNumber': '6269',
#     'section': 'TUT 101',
#     'location': 'RCH 302',
#     'enrolCap': '53',
#     'enrolTotal': '48',
#     'time': '01:30-02:20M',
#     'instructor': None},
#    {'classNumber': '6270',
#     'section': 'TUT 102',
#     'location': 'RCH 302',
#     'enrolCap': '53',
#     'enrolTotal': '50',
#     'time': '09:30-10:20T',
#     'instructor': None},
#    {'classNumber': '6271',
#     'section': 'TUT 103',
#     'location': 'RCH 302',
#     'enrolCap': '53',
#     'enrolTotal': '28',
#     'time': '09:30-10:20Th',
#     'instructor': None},
#    {'classNumber': '6264',
#     'section': 'LEC 002',
#     'location': 'Online',
#     'enrolCap': '146',
#     'enrolTotal': '117',
#     'time': '',
#     'instructor': 'Mintah,Comfort'},
#    {'classNumber': '6272',
#     'section': 'TUT 104',
#     'location': 'RCH 302',
#     'enrolCap': '49',
#     'enrolTotal': '47',
#     'time': '08:30-09:20M',
#     'instructor': None},
#    {'classNumber': '6273',
#     'section': 'TUT 105',
#     'location': 'RCH 302',
#     'enrolCap': '49',
#     'enrolTotal': '47',
#     'time': '08:30-09:20W',
#     'instructor': None},
#    {'classNumber': '6274',
#     'section': 'TUT 106',
#     'location': 'RCH 302',
#     'enrolCap': '48',
#     'enrolTotal': '23',
#     'time': '08:30-09:20F',
#     'instructor': None},
#    {'classNumber': '6265',
#     'section': 'LEC 003',
#     'location': 'Online',
#     'enrolCap': '78',
#     'enrolTotal': '68',
#     'time': '',
#     'instructor': 'Scott,Matthew'},
#    {'classNumber': '6275',
#     'section': 'TUT 107',
#     'location': 'RCH 309',
#     'enrolCap': '26',
#     'enrolTotal': '25',
#     'time': '02:30-03:20M',
#     'instructor': None},
#    {'classNumber': '6276',
#     'section': 'TUT 108',
#     'location': 'RCH 309',
#     'enrolCap': '26',
#     'enrolTotal': '25',
#     'time': '10:30-11:20T',
#     'instructor': None},
#    {'classNumber': '6277',
#     'section': 'TUT 109',
#     'location': 'RCH 309',
#     'enrolCap': '26',
#     'enrolTotal': '18',
#     'time': '10:30-11:20Th',
#     'instructor': None},
#    {'classNumber': '6266',
#     'section': 'LEC 004',
#     'location': 'Online',
#     'enrolCap': '119',
#     'enrolTotal': '89',
#     'time': '',
#     'instructor': 'Tatarko,Kateryna'},
#    {'classNumber': '6278',
#     'section': 'TUT 110',
#     'location': 'CPH 3604',
#     'enrolCap': '40',
#     'enrolTotal': '37',
#     'time': '08:30-09:20M',
#     'instructor': None},
#    {'classNumber': '6279',
#     'section': 'TUT 111',
#     'location': 'CPH 3604',
#     'enrolCap': '40',
#     'enrolTotal': '33',
#     'time': '08:30-09:20W',
#     'instructor': None},
#    {'classNumber': '6374',
#     'section': 'TUT 112',
#     'location': 'CPH 3604',
#     'enrolCap': '39',
#     'enrolTotal': '19',
#     'time': '08:30-09:20F',
#     'instructor': None},
#    {'classNumber': '6267',
#     'section': 'LEC 005',
#     'location': 'Online',
#     'enrolCap': '110',
#     'enrolTotal': '97',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '6460',
#     'section': 'TUT 113',
#     'location': 'E7 3343',
#     'enrolCap': '37',
#     'enrolTotal': '33',
#     'time': '04:30-05:20M',
#     'instructor': None},
#    {'classNumber': '6461',
#     'section': 'TUT 114',
#     'location': 'RCH 103',
#     'enrolCap': '37',
#     'enrolTotal': '33',
#     'time': '04:30-05:20W',
#     'instructor': None},
#    {'classNumber': '6462',
#     'section': 'TUT 115',
#     'location': 'RCH 103',
#     'enrolCap': '36',
#     'enrolTotal': '31',
#     'time': '03:30-04:20F',
#     'instructor': None},
#    {'classNumber': '6268',
#     'section': 'LEC 006',
#     'location': 'Online',
#     'enrolCap': '110',
#     'enrolTotal': '96',
#     'time': '',
#     'instructor': 'Nelson,Jen'},
#    {'classNumber': '6486',
#     'section': 'TUT 116',
#     'location': 'E7 3343',
#     'enrolCap': '37',
#     'enrolTotal': '32',
#     'time': '02:30-03:20M',
#     'instructor': None},
#    {'classNumber': '6487',
#     'section': 'TUT 117',
#     'location': 'E7 3343',
#     'enrolCap': '37',
#     'enrolTotal': '34',
#     'time': '04:00-04:50W',
#     'instructor': None},
#    {'classNumber': '6633',
#     'section': 'TUT 118',
#     'location': 'E7 3343',
#     'enrolCap': '36',
#     'enrolTotal': '30',
#     'time': '02:30-03:20F',
#     'instructor': None},
#    {'classNumber': '6373',
#     'section': 'LEC 007',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '114',
#     'time': '',
#     'instructor': 'Beltaos,Andrew'},
#    {'classNumber': '6831',
#     'section': 'TUT 119',
#     'location': 'E7 3343',
#     'enrolCap': '40',
#     'enrolTotal': '39',
#     'time': '10:30-11:20M',
#     'instructor': None},
#    {'classNumber': '6832',
#     'section': 'TUT 120',
#     'location': 'E7 3343',
#     'enrolCap': '40',
#     'enrolTotal': '40',
#     'time': '10:30-11:20W',
#     'instructor': None},
#    {'classNumber': '9618',
#     'section': 'TUT 121',
#     'location': 'RCH 105',
#     'enrolCap': '40',
#     'enrolTotal': '35',
#     'time': '03:30-04:20Th',
#     'instructor': None},
#    {'classNumber': '6632',
#     'section': 'LEC 008',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '97',
#     'time': '',
#     'instructor': 'Beltaos,Andrew'},
#    {'classNumber': '9619',
#     'section': 'TUT 122',
#     'location': 'E7 3343',
#     'enrolCap': '40',
#     'enrolTotal': '40',
#     'time': '11:30-12:20T',
#     'instructor': None},
#    {'classNumber': '9620',
#     'section': 'TUT 123',
#     'location': 'E7 3343',
#     'enrolCap': '40',
#     'enrolTotal': '32',
#     'time': '01:30-02:20T',
#     'instructor': None},
#    {'classNumber': '9621',
#     'section': 'TUT 124',
#     'location': 'E7 3343',
#     'enrolCap': '40',
#     'enrolTotal': '25',
#     'time': '11:30-12:20Th',
#     'instructor': None},
#    {'classNumber': '6830',
#     'section': 'LEC 009',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '95',
#     'time': '',
#     'instructor': 'Nelson,Jen'},
#    {'classNumber': '9622',
#     'section': 'TUT 125',
#     'location': 'RCH 105',
#     'enrolCap': '34',
#     'enrolTotal': '31',
#     'time': '01:30-02:20M',
#     'instructor': None},
#    {'classNumber': '9623',
#     'section': 'TUT 126',
#     'location': 'RCH 105',
#     'enrolCap': '33',
#     'enrolTotal': '32',
#     'time': '01:30-02:20W',
#     'instructor': None},
#    {'classNumber': '9624',
#     'section': 'TUT 127',
#     'location': 'RCH 105',
#     'enrolCap': '33',
#     'enrolTotal': '32',
#     'time': '01:30-02:20F',
#     'instructor': None},
#    {'classNumber': '11756',
#     'section': 'LEC 010',
#     'location': 'Online',
#     'enrolCap': '159',
#     'enrolTotal': '4',
#     'time': '',
#     'instructor': 'Scott,Matthew'},
#    {'classNumber': '11766',
#     'section': 'TUT 128',
#     'location': '',
#     'enrolCap': '159',
#     'enrolTotal': '4',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11757',
#     'section': 'LEC 011',
#     'location': 'Online',
#     'enrolCap': '146',
#     'enrolTotal': '6',
#     'time': '',
#     'instructor': 'Mintah,Comfort'},
#    {'classNumber': '11767',
#     'section': 'TUT 129',
#     'location': '',
#     'enrolCap': '146',
#     'enrolTotal': '6',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11758',
#     'section': 'LEC 012',
#     'location': 'Online',
#     'enrolCap': '78',
#     'enrolTotal': '1',
#     'time': '',
#     'instructor': 'Scott,Matthew'},
#    {'classNumber': '11768',
#     'section': 'TUT 130',
#     'location': '',
#     'enrolCap': '78',
#     'enrolTotal': '1',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11759',
#     'section': 'LEC 013',
#     'location': 'Online',
#     'enrolCap': '119',
#     'enrolTotal': '1',
#     'time': '',
#     'instructor': 'Tatarko,Kateryna'},
#    {'classNumber': '11769',
#     'section': 'TUT 131',
#     'location': '',
#     'enrolCap': '119',
#     'enrolTotal': '1',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11760',
#     'section': 'LEC 014',
#     'location': 'Online',
#     'enrolCap': '110',
#     'enrolTotal': '5',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11770',
#     'section': 'TUT 132',
#     'location': '',
#     'enrolCap': '110',
#     'enrolTotal': '5',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11761',
#     'section': 'LEC 015',
#     'location': 'Online',
#     'enrolCap': '110',
#     'enrolTotal': '4',
#     'time': '',
#     'instructor': 'Nelson,Jen'},
#    {'classNumber': '11771',
#     'section': 'TUT 133',
#     'location': '',
#     'enrolCap': '110',
#     'enrolTotal': '4',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11762',
#     'section': 'LEC 016',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '1',
#     'time': '',
#     'instructor': 'Beltaos,Andrew'},
#    {'classNumber': '11772',
#     'section': 'TUT 134',
#     'location': '',
#     'enrolCap': '120',
#     'enrolTotal': '1',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11763',
#     'section': 'LEC 017',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '1',
#     'time': '',
#     'instructor': 'Beltaos,Andrew'},
#    {'classNumber': '11773',
#     'section': 'TUT 135',
#     'location': '',
#     'enrolCap': '120',
#     'enrolTotal': '1',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11764',
#     'section': 'LEC 018',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '7',
#     'time': '',
#     'instructor': 'Nelson,Jen'},
#    {'classNumber': '11774',
#     'section': 'TUT 136',
#     'location': '',
#     'enrolCap': '100',
#     'enrolTotal': '7',
#     'time': '',
#     'instructor': None}]},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '117',
#   'units': '0.5',
#   'title': 'Calculus 1 for Engineering',
#   'notes': '',
#   'classes': [{'classNumber': '6117',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '129',
#     'time': '',
#     'instructor': "D'Alessio,Serge"},
#    {'classNumber': '6219',
#     'section': 'TUT 101',
#     'location': 'E7 4043',
#     'enrolCap': '50',
#     'enrolTotal': '44',
#     'time': '10:30-11:20W',
#     'instructor': None},
#    {'classNumber': '6220',
#     'section': 'TUT 102',
#     'location': 'E7 4043',
#     'enrolCap': '50',
#     'enrolTotal': '45',
#     'time': '10:30-11:20M',
#     'instructor': None},
#    {'classNumber': '6221',
#     'section': 'TUT 103',
#     'location': 'E7 4043',
#     'enrolCap': '50',
#     'enrolTotal': '40',
#     'time': '10:30-11:20T',
#     'instructor': None},
#    {'classNumber': '6118',
#     'section': 'LEC 002',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '128',
#     'time': '',
#     'instructor': "D'Alessio,Serge"},
#    {'classNumber': '6222',
#     'section': 'TUT 104',
#     'location': 'E7 4053',
#     'enrolCap': '50',
#     'enrolTotal': '45',
#     'time': '11:30-12:20Th',
#     'instructor': None},
#    {'classNumber': '6223',
#     'section': 'TUT 105',
#     'location': 'E7 4053',
#     'enrolCap': '50',
#     'enrolTotal': '42',
#     'time': '11:30-12:20M',
#     'instructor': None},
#    {'classNumber': '6224',
#     'section': 'TUT 106',
#     'location': 'E7 4053',
#     'enrolCap': '50',
#     'enrolTotal': '41',
#     'time': '11:30-12:20T',
#     'instructor': None},
#    {'classNumber': '6119',
#     'section': 'LEC 003',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '141',
#     'time': '',
#     'instructor': 'Wang,cz'},
#    {'classNumber': '6305',
#     'section': 'TUT 107',
#     'location': 'E7 4417',
#     'enrolCap': '50',
#     'enrolTotal': '45',
#     'time': '03:30-04:20Th',
#     'instructor': None},
#    {'classNumber': '6306',
#     'section': 'TUT 108',
#     'location': 'E7 4417',
#     'enrolCap': '50',
#     'enrolTotal': '52',
#     'time': '03:30-04:20T',
#     'instructor': None},
#    {'classNumber': '6326',
#     'section': 'TUT 109',
#     'location': 'E7 4417',
#     'enrolCap': '50',
#     'enrolTotal': '44',
#     'time': '03:30-04:20W',
#     'instructor': None},
#    {'classNumber': '6307',
#     'section': 'LEC 004',
#     'location': 'Online',
#     'enrolCap': '122',
#     'enrolTotal': '113',
#     'time': '',
#     'instructor': 'Kohandel,Mohammad'},
#    {'classNumber': '6327',
#     'section': 'TUT 110',
#     'location': 'QNC 1502',
#     'enrolCap': '61',
#     'enrolTotal': '58',
#     'time': '01:30-02:20T',
#     'instructor': None},
#    {'classNumber': '6463',
#     'section': 'TUT 111',
#     'location': 'QNC 1502',
#     'enrolCap': '61',
#     'enrolTotal': '55',
#     'time': '09:30-10:20F',
#     'instructor': None},
#    {'classNumber': '6325',
#     'section': 'LEC 005',
#     'location': 'Online',
#     'enrolCap': '54',
#     'enrolTotal': '141',
#     'time': '',
#     'instructor': 'Kohandel,Mohammad'},
#    {'classNumber': '6488',
#     'section': 'TUT 113',
#     'location': 'STC 0040',
#     'enrolCap': '51',
#     'enrolTotal': '47',
#     'time': '10:30-11:20W',
#     'instructor': None},
#    {'classNumber': '6489',
#     'section': 'TUT 114',
#     'location': 'STC 0040',
#     'enrolCap': '51',
#     'enrolTotal': '48',
#     'time': '09:30-10:20T',
#     'instructor': None},
#    {'classNumber': '6515',
#     'section': 'TUT 115',
#     'location': 'STC 0040',
#     'enrolCap': '52',
#     'enrolTotal': '46',
#     'time': '10:30-11:20F',
#     'instructor': None},
#    {'classNumber': '11528',
#     'section': 'LEC 006',
#     'location': 'Online',
#     'enrolCap': '123',
#     'enrolTotal': '3',
#     'time': '',
#     'instructor': 'Kohandel,Mohammad'},
#    {'classNumber': '6485',
#     'section': 'TUT 112',
#     'location': 'Online',
#     'enrolCap': '123',
#     'enrolTotal': '3',
#     'time': '02:30-03:20Th',
#     'instructor': None},
#    {'classNumber': '11705',
#     'section': 'LEC 007',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '13',
#     'time': '',
#     'instructor': "D'Alessio,Serge"},
#    {'classNumber': '11711',
#     'section': 'TUT 116',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '13',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11706',
#     'section': 'LEC 008',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '9',
#     'time': '',
#     'instructor': "D'Alessio,Serge"},
#    {'classNumber': '11712',
#     'section': 'TUT 117',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '9',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11707',
#     'section': 'LEC 009',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '15',
#     'time': '',
#     'instructor': 'Wang,cz'},
#    {'classNumber': '11713',
#     'section': 'TUT 118',
#     'location': 'Online',
#     'enrolCap': '140',
#     'enrolTotal': '15',
#     'time': '',
#     'instructor': None},
#    {'classNumber': '11708',
#     'section': 'LEC 010',
#     'location': 'Online',
#     'enrolCap': '54',
#     'enrolTotal': '9',
#     'time': '',
#     'instructor': 'Kohandel,Mohammad'},
#    {'classNumber': '11714',
#     'section': 'TUT 119',
#     'location': 'Online',
#     'enrolCap': '54',
#     'enrolTotal': '9',
#     'time': '',
#     'instructor': None}]},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '124',
#   'units': '0.5',
#   'title': 'Calc and Vector Alg for Kin',
#   'classes': [{'classNumber': '6394',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '280',
#     'enrolTotal': '261',
#     'time': '',
#     'instructor': 'Resch,Janelle'},
#    {'classNumber': '6395',
#     'section': 'TUT 101',
#     'location': 'Online',
#     'enrolCap': '280',
#     'enrolTotal': '261',
#     'time': '',
#     'instructor': 'Resch,Janelle'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '127',
#   'units': '0.5',
#   'title': 'Calculus 1 for the Sciences',
#   'classes': [{'classNumber': '6120',
#     'section': 'LEC 001',
#     'location': 'STC 1012',
#     'enrolCap': '75',
#     'enrolTotal': '72',
#     'time': '08:30-09:20MWF',
#     'instructor': None},
#    {'classNumber': '6121',
#     'section': 'LEC 002',
#     'location': 'STC 0040',
#     'enrolCap': '75',
#     'enrolTotal': '75',
#     'time': '09:30-10:20MWF',
#     'instructor': 'Girelli,Florian'},
#    {'classNumber': '6122',
#     'section': 'LEC 003',
#     'location': 'MC 2065',
#     'enrolCap': '75',
#     'enrolTotal': '75',
#     'time': '10:30-11:20MWF',
#     'instructor': 'McGrath,Paul'},
#    {'classNumber': '6123',
#     'section': 'LEC 004',
#     'location': 'MC 2065',
#     'enrolCap': '75',
#     'enrolTotal': '73',
#     'time': '11:30-12:20MWF',
#     'instructor': 'Mahmoud,Amena'},
#    {'classNumber': '6124',
#     'section': 'LEC 005',
#     'location': 'STC 0040',
#     'enrolCap': '75',
#     'enrolTotal': '72',
#     'time': '12:30-01:20MWF',
#     'instructor': 'Ingalls,Brian'},
#    {'classNumber': '6259',
#     'section': 'LEC 006',
#     'location': 'MC 2065',
#     'enrolCap': '75',
#     'enrolTotal': '71',
#     'time': '03:30-04:20MWF',
#     'instructor': 'McGrath,Paul'},
#    {'classNumber': '6302',
#     'section': 'LEC 007',
#     'location': 'STC 0010',
#     'enrolCap': '75',
#     'enrolTotal': '70',
#     'time': '09:30-10:20MWF',
#     'instructor': 'Wang,Greg'},
#    {'classNumber': '6303',
#     'section': 'LEC 008',
#     'location': 'STC 0010',
#     'enrolCap': '75',
#     'enrolTotal': '70',
#     'time': '10:30-11:20MWF',
#     'instructor': 'Woody,Owen'},
#    {'classNumber': '6579',
#     'section': 'LEC 009',
#     'location': 'STC 0010',
#     'enrolCap': '75',
#     'enrolTotal': '69',
#     'time': '11:30-12:20MWF',
#     'instructor': None},
#    {'classNumber': '6816',
#     'section': 'LEC 010',
#     'location': 'STC 0010',
#     'enrolCap': '75',
#     'enrolTotal': '68',
#     'time': '12:30-01:20MWF',
#     'instructor': None},
#    {'classNumber': '8194',
#     'section': 'LEC 081',
#     'location': 'Online',
#     'enrolCap': '300',
#     'enrolTotal': '257',
#     'time': '',
#     'instructor': 'Dunbar,Fiona'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '128',
#   'units': '0.5',
#   'title': 'Calculus 2 for the Sciences',
#   'classes': [{'classNumber': '8193',
#     'section': 'LEC 081',
#     'location': 'Online',
#     'enrolCap': '200',
#     'enrolTotal': '117',
#     'time': '',
#     'instructor': 'Woody,Owen'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '135',
#   'units': '0.5',
#   'title': 'Algebra for Hons Mathematics',
#   'classes': [{'classNumber': '6127',
#     'section': 'LEC 001',
#     'location': 'MC 4020',
#     'enrolCap': '63',
#     'enrolTotal': '61',
#     'time': '08:30-09:20MWF',
#     'instructor': 'Girard,Mark'},
#    {'classNumber': '6128',
#     'section': 'LEC 002',
#     'location': 'MC 4020',
#     'enrolCap': '61',
#     'enrolTotal': '60',
#     'time': '10:30-11:20MWF',
#     'instructor': 'Koeller,Judith Ann'},
#    {'classNumber': '6129',
#     'section': 'LEC 003',
#     'location': 'MC 4020',
#     'enrolCap': '61',
#     'enrolTotal': '60',
#     'time': '12:30-01:20MWF',
#     'instructor': 'Wang,Jerry'},
#    {'classNumber': '6130',
#     'section': 'LEC 004',
#     'location': 'MC 4020',
#     'enrolCap': '60',
#     'enrolTotal': '58',
#     'time': '02:30-03:20MWF',
#     'instructor': 'Sullivan,Matthew'},
#    {'classNumber': '6131',
#     'section': 'LEC 005',
#     'location': 'MC 4021',
#     'enrolCap': '60',
#     'enrolTotal': '59',
#     'time': '09:00-09:50MWF',
#     'instructor': 'Koeller,Judith Ann'},
#    {'classNumber': '6439',
#     'section': 'LEC 006',
#     'location': 'MC 4021',
#     'enrolCap': '60',
#     'enrolTotal': '56',
#     'time': '11:00-11:50MWF',
#     'instructor': 'Mosunov,Anton'},
#    {'classNumber': '6627',
#     'section': 'LEC 007',
#     'location': 'MC 4021',
#     'enrolCap': '60',
#     'enrolTotal': '59',
#     'time': '01:00-01:50MWF',
#     'instructor': 'Mosunov,Anton'},
#    {'classNumber': '6665',
#     'section': 'LEC 008',
#     'location': 'MC 4021',
#     'enrolCap': '62',
#     'enrolTotal': '59',
#     'time': '03:00-03:50MWF',
#     'instructor': 'Knight,Emma'},
#    {'classNumber': '6666',
#     'section': 'LEC 009',
#     'location': 'MC 4061',
#     'enrolCap': '61',
#     'enrolTotal': '61',
#     'time': '09:30-10:20MWF',
#     'instructor': 'Knoll,Carrie'},
#    {'classNumber': '6667',
#     'section': 'LEC 010',
#     'location': 'MC 1085',
#     'enrolCap': '76',
#     'enrolTotal': '70',
#     'time': '11:30-12:20MWF',
#     'instructor': 'Knoll,Carrie'},
#    {'classNumber': '6668',
#     'section': 'LEC 011',
#     'location': 'MC 4061',
#     'enrolCap': '60',
#     'enrolTotal': '55',
#     'time': '01:30-02:20MWF',
#     'instructor': 'Bauman,Shane'},
#    {'classNumber': '6669',
#     'section': 'LEC 012',
#     'location': 'MC 4061',
#     'enrolCap': '60',
#     'enrolTotal': '51',
#     'time': '03:30-04:20MWF',
#     'instructor': 'Bauman,Shane'},
#    {'classNumber': '6670',
#     'section': 'LEC 013',
#     'location': 'MC 4059',
#     'enrolCap': '60',
#     'enrolTotal': '50',
#     'time': '10:00-10:50MWF',
#     'instructor': 'Wang,Jerry'},
#    {'classNumber': '6671',
#     'section': 'LEC 014',
#     'location': 'MC 4059',
#     'enrolCap': '60',
#     'enrolTotal': '52',
#     'time': '12:00-12:50MWF',
#     'instructor': None},
#    {'classNumber': '6672',
#     'section': 'LEC 015',
#     'location': 'MC 4059',
#     'enrolCap': '60',
#     'enrolTotal': '48',
#     'time': '02:00-02:50MWF',
#     'instructor': 'Humeniuk,Adam'},
#    {'classNumber': '6673',
#     'section': 'LEC 016',
#     'location': 'MC 4059',
#     'enrolCap': '60',
#     'enrolTotal': '58',
#     'time': '04:00-04:50MWF',
#     'instructor': None},
#    {'classNumber': '6674',
#     'section': 'LEC 017',
#     'location': 'MC 1085',
#     'enrolCap': '76',
#     'enrolTotal': '70',
#     'time': '08:30-09:20MWF',
#     'instructor': None},
#    {'classNumber': '6675',
#     'section': 'LEC 018',
#     'location': 'MC 1085',
#     'enrolCap': '76',
#     'enrolTotal': '65',
#     'time': '12:30-01:20MWF',
#     'instructor': 'Kalashnikov,Elana'},
#    {'classNumber': '6676',
#     'section': 'LEC 019',
#     'location': 'MC 1085',
#     'enrolCap': '76',
#     'enrolTotal': '67',
#     'time': '02:30-03:20MWF',
#     'instructor': None},
#    {'classNumber': '6677',
#     'section': 'LEC 020',
#     'location': 'STP 105',
#     'enrolCap': '122',
#     'enrolTotal': '103',
#     'time': '10:30-11:20MWF',
#     'instructor': 'Abdelkader Mahmoud,Ali Assem'},
#    {'classNumber': '6678',
#     'section': 'LEC 021',
#     'location': 'STC 0040',
#     'enrolCap': '77',
#     'enrolTotal': '73',
#     'time': '01:30-02:20MWF',
#     'instructor': 'Abdelkader Mahmoud,Ali Assem'},
#    {'classNumber': '6679',
#     'section': 'LEC 022',
#     'location': 'STC 0040',
#     'enrolCap': '77',
#     'enrolTotal': '69',
#     'time': '03:30-04:20MWF',
#     'instructor': 'Abdelkader Mahmoud,Ali Assem'},
#    {'classNumber': '10310',
#     'section': 'LEC 081',
#     'location': 'Online',
#     'enrolCap': '600',
#     'enrolTotal': '401',
#     'time': '',
#     'instructor': 'Kuo,Wentang'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '136',
#   'units': '0.5',
#   'title': 'Linear Algebra 1 (Hon Math)',
#   'classes': [{'classNumber': '8190',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '400',
#     'enrolTotal': '174',
#     'time': '',
#     'instructor': 'Guglielmi,Roberto'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '137',
#   'units': '0.5',
#   'title': 'Calculus 1 for Honours Math',
#   'notes': '',
#   'classes': [{'classNumber': '6133',
#     'section': 'LEC 001',
#     'location': 'MC 4020',
#     'enrolCap': '63',
#     'enrolTotal': '63',
#     'time': '09:30-10:20MWF',
#     'instructor': 'Albayrak,Seda'},
#    {'classNumber': '6134',
#     'section': 'LEC 002',
#     'location': 'MC 4020',
#     'enrolCap': '61',
#     'enrolTotal': '60',
#     'time': '11:30-12:20MWF',
#     'instructor': 'Albayrak,Seda'},
#    {'classNumber': '6135',
#     'section': 'LEC 003',
#     'location': 'MC 4020',
#     'enrolCap': '61',
#     'enrolTotal': '60',
#     'time': '01:30-02:20MWF',
#     'instructor': 'Albayrak,Seda'},
#    {'classNumber': '6136',
#     'section': 'LEC 004',
#     'location': 'MC 4020',
#     'enrolCap': '60',
#     'enrolTotal': '58',
#     'time': '03:30-04:20MWF',
#     'instructor': 'Ursu,Dan'},
#    {'classNumber': '6137',
#     'section': 'LEC 005',
#     'location': 'MC 4021',
#     'enrolCap': '60',
#     'enrolTotal': '59',
#     'time': '10:00-10:50MWF',
#     'instructor': 'Dupont,Edward'},
#    {'classNumber': '6138',
#     'section': 'LEC 006',
#     'location': 'MC 4021',
#     'enrolCap': '60',
#     'enrolTotal': '56',
#     'time': '12:00-12:50MWF',
#     'instructor': 'Dupont,Edward'},
#    {'classNumber': '6139',
#     'section': 'LEC 007',
#     'location': 'MC 4021',
#     'enrolCap': '60',
#     'enrolTotal': '59',
#     'time': '02:00-02:50MWF',
#     'instructor': 'Dupont,Edward'},
#    {'classNumber': '6140',
#     'section': 'LEC 008',
#     'location': 'MC 4021',
#     'enrolCap': '62',
#     'enrolTotal': '61',
#     'time': '04:00-04:50MWF',
#     'instructor': 'Kotecha,Sachin'},
#    {'classNumber': '6628',
#     'section': 'LEC 009',
#     'location': 'MC 4061',
#     'enrolCap': '61',
#     'enrolTotal': '61',
#     'time': '08:30-09:20MWF',
#     'instructor': 'Reid,Hayley Melissa'},
#    {'classNumber': '10312',
#     'section': 'LEC 010',
#     'location': 'MC 1085',
#     'enrolCap': '76',
#     'enrolTotal': '73',
#     'time': '10:30-11:20MWF',
#     'instructor': 'Wolczuk,Dan'},
#    {'classNumber': '10313',
#     'section': 'LEC 011',
#     'location': 'MC 4061',
#     'enrolCap': '60',
#     'enrolTotal': '55',
#     'time': '12:30-01:20MWF',
#     'instructor': 'Wolczuk,Dan'},
#    {'classNumber': '10314',
#     'section': 'LEC 012',
#     'location': 'MC 4061',
#     'enrolCap': '60',
#     'enrolTotal': '51',
#     'time': '02:30-03:20MWF',
#     'instructor': 'Kotecha,Sachin'},
#    {'classNumber': '10315',
#     'section': 'LEC 013',
#     'location': 'MC 4059',
#     'enrolCap': '60',
#     'enrolTotal': '51',
#     'time': '09:00-09:50MWF',
#     'instructor': 'Hamilton,Jordan'},
#    {'classNumber': '10316',
#     'section': 'LEC 014',
#     'location': 'MC 4059',
#     'enrolCap': '60',
#     'enrolTotal': '52',
#     'time': '11:00-11:50MWF',
#     'instructor': 'Hamilton,Jordan'},
#    {'classNumber': '10317',
#     'section': 'LEC 015',
#     'location': 'MC 4059',
#     'enrolCap': '60',
#     'enrolTotal': '37',
#     'time': '01:00-01:50MWF',
#     'instructor': 'Reid,Hayley Melissa'},
#    {'classNumber': '10318',
#     'section': 'LEC 016',
#     'location': 'MC 4059',
#     'enrolCap': '60',
#     'enrolTotal': '57',
#     'time': '03:00-03:50MWF',
#     'instructor': 'Hamilton,Jordan'},
#    {'classNumber': '10319',
#     'section': 'LEC 017',
#     'location': 'MC 1085',
#     'enrolCap': '76',
#     'enrolTotal': '69',
#     'time': '09:30-10:20MWF',
#     'instructor': 'Wolczuk,Dan'},
#    {'classNumber': '10320',
#     'section': 'LEC 018',
#     'location': 'MC 1085',
#     'enrolCap': '76',
#     'enrolTotal': '65',
#     'time': '01:30-02:20MWF',
#     'instructor': 'Park,Douglas'},
#    {'classNumber': '10321',
#     'section': 'LEC 019',
#     'location': 'MC 1085',
#     'enrolCap': '76',
#     'enrolTotal': '67',
#     'time': '03:30-04:20MWF',
#     'instructor': 'Reid,Hayley Melissa'},
#    {'classNumber': '10322',
#     'section': 'LEC 020',
#     'location': 'STP 105',
#     'enrolCap': '122',
#     'enrolTotal': '100',
#     'time': '11:30-12:20MWF',
#     'instructor': 'Kotecha,Sachin'},
#    {'classNumber': '8204',
#     'section': 'LEC 021',
#     'location': 'Online',
#     'enrolCap': '600',
#     'enrolTotal': '389',
#     'time': '',
#     'instructor': 'Castaneda Santos,Diana'},
#    {'classNumber': '10311',
#     'section': 'LEC 022',
#     'location': 'Online',
#     'enrolCap': '150',
#     'enrolTotal': '95',
#     'time': '',
#     'instructor': 'Poulin,Francis'},
#    {'classNumber': '11634',
#     'section': 'TUT 101',
#     'location': 'AL 116',
#     'enrolCap': '150',
#     'enrolTotal': '95',
#     'time': '10:00-10:50T',
#     'instructor': 'Poulin,Francis'}]},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '138',
#   'units': '0.5',
#   'title': 'Calculus 2 for Honours Math',
#   'classes': [{'classNumber': '8206',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '400',
#     'enrolTotal': '147',
#     'time': '',
#     'instructor': 'Garbary,Robert'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '145',
#   'units': '0.5',
#   'title': 'Algebra (Advanced Level)',
#   'classes': [{'classNumber': '6058',
#     'section': 'LEC 001',
#     'location': 'AHS 1689',
#     'enrolCap': '120',
#     'enrolTotal': '119',
#     'time': '01:30-02:20MWF',
#     'instructor': 'Jao,David'},
#    {'classNumber': '6765',
#     'section': 'LEC 002',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '64',
#     'time': '',
#     'instructor': 'Satriano,Matthew'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '147',
#   'units': '0.5',
#   'title': 'Calculus 1 (Advanced Level)',
#   'classes': [{'classNumber': '6060',
#     'section': 'LEC 001',
#     'location': 'AHS 1689',
#     'enrolCap': '120',
#     'enrolTotal': '118',
#     'time': '02:30-03:20MWF',
#     'instructor': 'Brannan,Michael'},
#    {'classNumber': '6768',
#     'section': 'LEC 002',
#     'location': 'Online',
#     'enrolCap': '120',
#     'enrolTotal': '56',
#     'time': '',
#     'instructor': 'Shum,Henry'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '207',
#   'units': '0.5',
#   'title': 'Cal 3 (Non-Specialist Level)',
#   'classes': [{'classNumber': '6455',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '28',
#     'time': '',
#     'instructor': 'Cramer,Zack'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '217',
#   'units': '0.5',
#   'title': 'Calculus 3 (Chemical Eng)',
#   'classes': [{'classNumber': '6062',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '72',
#     'time': '',
#     'instructor': 'Girelli,Florian'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '218',
#   'units': '0.5',
#   'title': 'Differential Equations (Eng)',
#   'classes': [{'classNumber': '6064',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '54',
#     'time': '',
#     'instructor': 'Lamb,Kevin'},
#    {'classNumber': '11853',
#     'section': 'TUT 101',
#     'location': 'E6 2024',
#     'enrolCap': '100',
#     'enrolTotal': '54',
#     'time': '10:30-11:20W',
#     'instructor': None}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '225',
#   'units': '0.5',
#   'title': 'Applied Linear Algebra 2',
#   'classes': [{'classNumber': '6457',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '33',
#     'time': '',
#     'instructor': 'Turner,Graeme'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '227',
#   'units': '0.5',
#   'title': 'Calculus 3 for Honours Physics',
#   'notes': '',
#   'classes': [{'classNumber': '6065',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '96',
#     'time': '',
#     'instructor': 'McGrath,Paul'},
#    {'classNumber': '10730',
#     'section': 'TUT 101',
#     'location': 'MC 2054',
#     'enrolCap': '50',
#     'enrolTotal': '49',
#     'time': '11:30-12:20M',
#     'instructor': 'McGrath,Paul'},
#    {'classNumber': '10731',
#     'section': 'TUT 102',
#     'location': 'MC 2054',
#     'enrolCap': '50',
#     'enrolTotal': '47',
#     'time': '11:30-12:20W',
#     'instructor': 'McGrath,Paul'},
#    {'classNumber': '10729',
#     'section': 'LEC 002',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '61',
#     'time': '',
#     'instructor': 'McGrath,Paul'}]},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '228',
#   'units': '0.5',
#   'title': 'Differ Equations (Phys&Chem)',
#   'classes': [{'classNumber': '6068',
#     'section': 'LEC 001',
#     'location': 'MC 2066',
#     'enrolCap': '96',
#     'enrolTotal': '50',
#     'time': '09:30-10:20MWF',
#     'instructor': 'Milne,Russell'},
#    {'classNumber': '6189',
#     'section': 'LEC 081',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '53',
#     'time': '',
#     'instructor': 'Fitzsimmons,Max'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '229',
#   'units': '0.5',
#   'title': 'Intro to Combinator (Non-Spec)',
#   'classes': [{'classNumber': '6498',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '16',
#     'time': '',
#     'instructor': 'Levit,Maxwell'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '235',
#   'units': '0.5',
#   'title': 'Linear Algebra 2 (Hon Math)',
#   'classes': [{'classNumber': '6069',
#     'section': 'LEC 001',
#     'location': 'MC 1085',
#     'enrolCap': '75',
#     'enrolTotal': '75',
#     'time': '08:30-09:50TTh',
#     'instructor': None},
#    {'classNumber': '6070',
#     'section': 'LEC 002',
#     'location': 'MC 1085',
#     'enrolCap': '75',
#     'enrolTotal': '75',
#     'time': '01:00-02:20TTh',
#     'instructor': None},
#    {'classNumber': '6071',
#     'section': 'LEC 003',
#     'location': 'MC 4021',
#     'enrolCap': '60',
#     'enrolTotal': '60',
#     'time': '10:00-11:20TTh',
#     'instructor': 'Rollick,Nickolas'},
#    {'classNumber': '6188',
#     'section': 'LEC 004',
#     'location': 'MC 4021',
#     'enrolCap': '60',
#     'enrolTotal': '60',
#     'time': '02:30-03:50TTh',
#     'instructor': 'Rollick,Nickolas'},
#    {'classNumber': '8207',
#     'section': 'LEC 005',
#     'location': 'Online',
#     'enrolCap': '600',
#     'enrolTotal': '455',
#     'time': '',
#     'instructor': 'Rubinstein,Michael'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '237',
#   'units': '0.5',
#   'title': 'Calculus 3 for Honours Math',
#   'classes': [{'classNumber': '6072',
#     'section': 'LEC 001',
#     'location': 'MC 1085',
#     'enrolCap': '75',
#     'enrolTotal': '75',
#     'time': '10:00-11:20TTh',
#     'instructor': 'Cramer,Zack'},
#    {'classNumber': '6073',
#     'section': 'LEC 002',
#     'location': 'MC 1085',
#     'enrolCap': '75',
#     'enrolTotal': '75',
#     'time': '02:30-03:50TTh',
#     'instructor': 'Cramer,Zack'},
#    {'classNumber': '6304',
#     'section': 'LEC 003',
#     'location': 'MC 4021',
#     'enrolCap': '60',
#     'enrolTotal': '60',
#     'time': '08:30-09:50TTh',
#     'instructor': 'Al-Faisal,Faisal'},
#    {'classNumber': '6317',
#     'section': 'LEC 004',
#     'location': 'MC 4021',
#     'enrolCap': '60',
#     'enrolTotal': '60',
#     'time': '01:00-02:20TTh',
#     'instructor': 'Al-Faisal,Faisal'},
#    {'classNumber': '10369',
#     'section': 'LEC 081',
#     'location': 'Online',
#     'enrolCap': '400',
#     'enrolTotal': '342',
#     'time': '',
#     'instructor': 'Tuncer Karabina,Burcu'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '239',
#   'units': '0.5',
#   'title': 'Intro to Combinatorics',
#   'notes': '',
#   'classes': [{'classNumber': '6074',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '300',
#     'enrolTotal': '280',
#     'time': '',
#     'instructor': 'Melczer,Steve'},
#    {'classNumber': '10962',
#     'section': 'TUT 101',
#     'location': 'Online',
#     'enrolCap': '50',
#     'enrolTotal': '50',
#     'time': '01:30-02:20M',
#     'instructor': 'Melczer,Steve'},
#    {'classNumber': '10963',
#     'section': 'TUT 102',
#     'location': 'Online',
#     'enrolCap': '50',
#     'enrolTotal': '49',
#     'time': '08:30-09:20W',
#     'instructor': 'Gao,Jane'},
#    {'classNumber': '10964',
#     'section': 'TUT 103',
#     'location': 'Online',
#     'enrolCap': '50',
#     'enrolTotal': '41',
#     'time': '08:30-09:20F',
#     'instructor': 'Melczer,Steve'},
#    {'classNumber': '10965',
#     'section': 'TUT 104',
#     'location': 'Online',
#     'enrolCap': '50',
#     'enrolTotal': '50',
#     'time': '06:30-07:20M',
#     'instructor': 'Melczer,Steve'},
#    {'classNumber': '10966',
#     'section': 'TUT 105',
#     'location': 'Online',
#     'enrolCap': '50',
#     'enrolTotal': '50',
#     'time': '09:30-10:20M',
#     'instructor': 'Gao,Jane'},
#    {'classNumber': '10967',
#     'section': 'TUT 106',
#     'location': 'Online',
#     'enrolCap': '50',
#     'enrolTotal': '40',
#     'time': '11:30-12:20F',
#     'instructor': 'Gao,Jane'},
#    {'classNumber': '6075',
#     'section': 'LEC 002',
#     'location': 'Online',
#     'enrolCap': '300',
#     'enrolTotal': '225',
#     'time': '',
#     'instructor': 'Smith-Roberge,Evelyne'},
#    {'classNumber': '10968',
#     'section': 'TUT 107',
#     'location': 'MC 4045',
#     'enrolCap': '50',
#     'enrolTotal': '30',
#     'time': '09:30-10:20M',
#     'instructor': 'Smith-Roberge,Evelyne'},
#    {'classNumber': '10969',
#     'section': 'TUT 108',
#     'location': 'MC 2034',
#     'enrolCap': '50',
#     'enrolTotal': '35',
#     'time': '09:30-10:20W',
#     'instructor': 'Smith-Roberge,Evelyne'},
#    {'classNumber': '10970',
#     'section': 'TUT 109',
#     'location': 'MC 4045',
#     'enrolCap': '50',
#     'enrolTotal': '31',
#     'time': '09:30-10:20F',
#     'instructor': 'Smith-Roberge,Evelyne'},
#    {'classNumber': '10971',
#     'section': 'TUT 110',
#     'location': 'MC 4045',
#     'enrolCap': '50',
#     'enrolTotal': '49',
#     'time': '01:30-02:20M',
#     'instructor': 'Yeats,Karen'},
#    {'classNumber': '10972',
#     'section': 'TUT 111',
#     'location': 'MC 2017',
#     'enrolCap': '50',
#     'enrolTotal': '50',
#     'time': '01:30-02:20W',
#     'instructor': 'Yeats,Karen'},
#    {'classNumber': '10973',
#     'section': 'TUT 112',
#     'location': 'MC 4045',
#     'enrolCap': '50',
#     'enrolTotal': '30',
#     'time': '01:30-02:20F',
#     'instructor': 'Yeats,Karen'}]},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '245',
#   'units': '0.5',
#   'title': 'Linear Algebra 2 (Adv Level)',
#   'classes': [{'classNumber': '6161',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '35',
#     'time': '',
#     'instructor': 'New,Stephen'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '247',
#   'units': '0.5',
#   'title': 'Calculus 3 (Advanced Level)',
#   'classes': [{'classNumber': '6162',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '19',
#     'time': '',
#     'instructor': 'Madill,Blake'}],
#   'notes': ''},
#  {'term': '1219',
#   'subjectCode': 'MATH',
#   'catalogNumber': '249',
#   'units': '0.5',
#   'title': 'Intro to Combinatorics (Adv)',
#   'classes': [{'classNumber': '6163',
#     'section': 'LEC 001',
#     'location': 'Online',
#     'enrolCap': '100',
#     'enrolTotal': '41',
#     'time': '01:30-02:20MWF',
#     'instructor': 'Geelen,Jim'}],
#   'notes': ''}]

# %%
# write courses to json
with open('data.json', 'w') as outfile:
    json.dump(courses, outfile)

# %% [markdown]
# Dump courses data to mongodb database

# %%
from pymongo import MongoClient
import os
from dotenv import load_dotenv

# take env vars from .env file
load_dotenv()
# Out:
# True

# %%
# get mongodb database using mongo client
# client = MongoClient(os.getenv('MONGO_DB_CONNECTION_STRING'))
# # insert data
# client['waterloo']['courses'].insert_many(courses)
